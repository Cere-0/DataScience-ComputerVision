# %% [markdown]
# # Practicas de Computer Vision

# %%
# Establecemos nuestras credenciales
key='<my key>'
endpoint='https://cb-dr-lab1.cognitiveservices.azure.com/'

# %%
# Conectamos con azure
# pip install azure-cognitiveservices-vision-computervision==0.7.0
from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from msrest.authentication import CognitiveServicesCredentials

client = ComputerVisionClient(endpoint,CognitiveServicesCredentials(key))

# %%
import vision
import os

# %matplotlib inline

# Obtenemos la imagen
image_path ='./dataRangers/data/vision/store-camera-1.jpg'

image_stream = open(image_path, "rb")

description = client.describe_image_in_stream(image_stream)
print(description)

vision.show_image_caption(image_path, description)
# Out:
# {'additional_properties': {}, 'tags': ['text', 'person', 'woman', 'store', 'shop'], 'captions': [<azure.cognitiveservices.vision.computervision.models._models_py3.ImageCaption object at 0x7f3bf6a3e770>], 'request_id': 'c1ebfd22-cb13-4a26-b077-dce8ce082625', 'metadata': <azure.cognitiveservices.vision.computervision.models._models_py3.ImageMetadata object at 0x7f3bf5ed95a0>}

# %%
image_path = './dataRangers/data/vision/store-camera-2.jpg'

image_stream = open(image_path, "rb")

description = client.describe_image_in_stream(image_stream)
print(description)
vision.show_image_caption(image_path,description)
# Out:
# {'additional_properties': {}, 'tags': ['text', 'person', 'woman', 'marketplace', 'shop'], 'captions': [<azure.cognitiveservices.vision.computervision.models._models_py3.ImageCaption object at 0x7f3bf4a1c670>], 'request_id': '0cf1ac34-3754-45e6-b405-e200ff97ed84', 'metadata': <azure.cognitiveservices.vision.computervision.models._models_py3.ImageMetadata object at 0x7f3bf4a0f040>}

# %%
image_path = './dataRangers/data/vision/store-camera-3.jpg'

image_stream = open(image_path, "rb")

description = client.describe_image_in_stream(image_stream)
print(description)
vision.show_image_caption(image_path,description)
# Out:
# {'additional_properties': {}, 'tags': ['text', 'marketplace', 'person', 'scene', 'produce', 'shop'], 'captions': [<azure.cognitiveservices.vision.computervision.models._models_py3.ImageCaption object at 0x7f3bf483db70>], 'request_id': '8233d68c-a362-4b86-8eb2-c4b274ec9b2f', 'metadata': <azure.cognitiveservices.vision.computervision.models._models_py3.ImageMetadata object at 0x7f3bf483d180>}

# %%
image_path = './dataRangers/data/vision/store-camera-1.jpg'

features = ['Description', 'Tags', 'Adult', 'Objects', 'Faces']

image_stream = open(image_path, "rb")

analysis = client.analyze_image_in_stream(image_stream, visual_features=features)

vision.show_image_analysis(image_path,analysis)

# %%
image_path = './dataRangers/data/vision/store-camera-2.jpg'

features = ['Description', 'Tags', 'Adult', 'Objects', 'Faces']

image_stream = open(image_path, "rb")

analysis = client.analyze_image_in_stream(image_stream, visual_features=features)

vision.show_image_analysis(image_path,analysis)

# %%
image_path = './dataRangers/data/vision/store-camera-3.jpg'

features = ['Description', 'Tags', 'Adult', 'Objects', 'Faces']

image_stream = open(image_path, "rb")

analysis = client.analyze_image_in_stream(image_stream, visual_features=features)

vision.show_image_analysis(image_path,analysis)

# %%
image_path = './dataRangers/data/vision/Cat1.jpg'

features = ['Description', 'Tags', 'Adult', 'Objects', 'Faces']

image_stream = open(image_path, "rb")

analysis = client.analyze_image_in_stream(image_stream, visual_features=features)

vision.show_image_analysis(image_path,analysis)

# %%
image_path = './dataRangers/data/vision/Cat2.jpeg'

features = ['Description', 'Tags', 'Adult', 'Objects', 'Faces']

image_stream = open(image_path, "rb")

analysis = client.analyze_image_in_stream(image_stream, visual_features=features)

vision.show_image_analysis(image_path,analysis)

# %% [markdown]
# ## FaceAPI

# %%
key = '<my key>'
endpoint = 'https://dr-face-lab2.cognitiveservices.azure.com/'

# %%
# !pip install azure-cognitiveservices-vision-face
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting azure-cognitiveservices-vision-face
#   Downloading azure_cognitiveservices_vision_face-0.6.0-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 571.0 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: msrest>=0.5.0 in /home/alejandro/.local/lib/python3.10/site-packages (from azure-cognitiveservices-vision-face) (0.7.0)
# Requirement already satisfied: azure-common~=1.1 in /home/alejandro/.local/lib/python3.10/site-packages (from azure-cognitiveservices-vision-face) (1.1.28)
# Requirement already satisfied: azure-core>=1.24.0 in /home/alejandro/.local/lib/python3.10/site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-face) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-face) (2019.11.28)
# Requirement already satisfied: requests~=2.16 in /usr/lib/python3/dist-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-face) (2.22.0)
# Requirement already satisfied: isodate>=0.6.0 in /home/alejandro/.local/lib/python3.10/site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-face) (0.6.1)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /home/alejandro/.local/lib/python3.10/site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-face) (1.3.1)
# Requirement already satisfied: six>=1.11.0 in /usr/lib/python3/dist-packages (from azure-core>=1.24.0->msrest>=0.5.0->azure-cognitiveservices-vision-face) (1.14.0)
# Requirement already satisfied: typing-extensions>=4.0.1 in /home/alejandro/.local/lib/python3.10/site-packages (from azure-core>=1.24.0->msrest>=0.5.0->azure-cognitiveservices-vision-face) (4.2.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/lib/python3/dist-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.0->azure-cognitiveservices-vision-face) (3.1.0)
# Installing collected packages: azure-cognitiveservices-vision-face
# Successfully installed azure-cognitiveservices-vision-face-0.6.0

# %%
# Conectamos con azure
# pip install azure-cognitiveservices-vision-computervision==0.7.0
from azure.cognitiveservices.vision.face import FaceClient
from msrest.authentication import CognitiveServicesCredentials

client = FaceClient(endpoint,CognitiveServicesCredentials(key))

# %%
import faces
import os
# %matplotlib inline

# %%
image_path = './dataRangers/data/vision/groupofpeople-1.jpg'

image_stream = open(image_path, "rb")

detected_faces = client.face.detect_with_stream(image=image_stream)

faces.show_faces(image_path, detected_faces, show_id=True)

# %%
image_path = './dataRangers/data/vision/groupofpeople-2.jpg'

image_stream = open(image_path, "rb")

detected_faces = client.face.detect_with_stream(image=image_stream)

faces.show_faces(image_path, detected_faces, show_id=True)

# %%
image_path = './dataRangers/data/vision/groupofpeople-1.jpg'

image_stream = open(image_path, "rb")

attributes = ['age', 'emotion']
detected_faces = client.face.detect_with_stream(image= image_stream, return_face_attributes=attributes)

faces.show_face_attributes(image_path, detected_faces)
